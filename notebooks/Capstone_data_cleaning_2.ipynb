# %%
import pandas as pd
import regex as re

# %%
caissabase = pd.read_csv('../data/caissabase_df.csv')
# Out:
# C:\Users\apcsm\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,9,10,12,13,14,16,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

# %%
caissabase = caissabase.drop(['Unnamed: 0'], axis = 1)

# %%
caissabase = caissabase[~caissabase['event'].str.contains('corr|rapid|blitz|bullet|exhibition|bltz| rpd |titled arena|titled tuesday|speed|titled tue|fast|\?', case = False, na = False)]

# %%
caissabase = pd.read_csv('../data/caissabase_df.csv')
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

# %%
for x in range (1,6):
    z = str(x) + 'w'
    y = str(x) + 'b'
    
    caissabase = caissabase[~caissabase[z].str.contains('Error', na = False)]
    caissabase = caissabase[~caissabase[y].str.contains('Error', na = False)]

# %%
caissabase = caissabase.loc[(caissabase['1w'] == 'e4')|(caissabase['1w'] == 'd4')|(caissabase['1w'] == 'Nf3')|(caissabase['1w'] == 'c4')|(caissabase['1w'] == 'g3')|(caissabase['1w'] == 'f4')|(caissabase['1w'] == 'b3')|(caissabase['1w'] == 'Nc3')|(caissabase['1w'] == 'b4')|(caissabase['1w'] == 'e3')|(caissabase['1w'] == 'd3')|(caissabase['1w'] == 'a3')|(caissabase['1w'] == 'g4')|(caissabase['1w'] == 'c3')|(caissabase['1w'] == 'h3')|(caissabase['1w'] == 'h4')|(caissabase['1w'] == 'Nh3')|(caissabase['1w'] == 'f3')|(caissabase['1w'] == 'a4')|(caissabase['1w'] == 'Na3')]

# %%
caissabase.to_csv('../data/caissabase_df.csv')

# %%
caissabase.head()
# Out:
#                 event           site        date round             white  \
# 0  Tel Aviv Int. 2021   Tel Aviv ISR  2021.11.29   2.4     Solomon, Asif
# 1   ch-NED Final 2021  Rotterdam NED  2021.11.29   3.1    Warmerdam, Max
# 2  Tel Aviv Int. 2021   Tel Aviv ISR  2021.11.29   2.1  Aizenberg, Benny
# 3  Tel Aviv Int. 2021   Tel Aviv ISR  2021.11.29   2.2        Dvoirys, S
# 4  Tel Aviv Int. 2021   Tel Aviv ISR  2021.11.29   2.5       Kantsler, B
#
#             black   result  black_elo black_fide_id black_title   eco  \
# 0    Kaganskiy, G  1/2-1/2     2251.0     4132025.0          FM   E46
# 1  Lai, Hing Ting      1-0     2450.0     1038257.0          IM   A18
# 2   Rozentalis, E  1/2-1/2     2517.0    12800023.0          GM  C60r
# 3     Vagman, Roy  1/2-1/2     1956.0     2828995.0          CM   B69
# 4    Zemach, Roee  1/2-1/2     2297.0     2818531.0          FM   E54
#
#    event_date       opening  \
# 0  2021.11.28  Nimzo-Indian
# 1  2021.11.27       English
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(caissabase['1w'].value_counts(dropna = False))
# Out:
# e4     1977467
# d4     1371496
# Nf3     353162
# c4      282893
# g3       27228
# f4       21166
# b3       19396
# Nc3       9021
# b4        7139
# e3        2260
# d3        1624
# a3        1424
# g4        1010
# c3         851
# h3         211
# h4         126
# Nh3        119
# f3          69
# a4          50
# Na3         47
# Name: 1w, dtype: int64

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(caissabase['event'].value_counts(dropna = False))
# Out:
# Open                                                   49763
# Corr                                                   29895
# Germany                                                18372
# Politiken Cup                                          12711
# Moscow                                                 12654
# Open A                                                 12392
# Duitsland tt                                           10792
# It Open                                                 9336
# Buenos Aires                                            7989
# PRO League Group Stage                                  7853
# Budapest                                                7719
# Hoogovens                                               6834
# It                                                      6682
# Chigorin Memorial                                       6604
# URS Ch, semi final                                      6422
# ...
